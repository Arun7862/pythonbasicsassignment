# %% [markdown]
# #  Theory

# %% [markdown]
# Ans-1:-
# NumPy, short for Numerical Python, is a fundamental library for numerical and scientific computing in Python.
# Numpy is effcient, simple, memory effcient, etc that way it is widly use.
#
# Ans-2:-
# Broadcasting in NumPy allows us to perform arithmetic operations on arrays of different shapes without reshaping them.
#
#
# Ans-3:-
# A Pandas DataFrame is a two-dimensional, size-mutable, tabular data structure with labeled axes (rows and columns).
#
# Ans-4:-
# The groupby() method in Pandas is used to group rows in a DataFrame based on the values in one or more columns.
#
# Ans-5:-
# Seaborn is a library for making statistical graphics. It builds on top of matplotlib and integrates closely with pandas data structures. Seaborn helps you explore and understand data.
#
#
# Ans-6:-
#  * Numpy stores homogeneous data, other hend Python stores heterogeneous Data.
#  * Numpy More memory-efficient due to contiguous storage and fixed data types, Python less memory-efficient as elements are stored as separate object.
#  * Numpy have fixed size, python have dynamic size.
#
# Ans-7:-
# A heatmap is a data visualization technique that uses color-coding to represent the magnitude of a variable across two dimensions.
#
# Ans-8:-
# Vectorized operations in NumPy enable the use of efficient, pre-compiled functions and mathematical operations on NumPy arrays and data sequences.
#
# Ans-9:-
#   * Matplotlib: Is often preferred for academic or highly customized plots because you can fine-tune just about any aspect of the figure, fonts, margins, axis scales, etc.
#   * Plotly: While still highly customizable, Plotly's real strength lies in interactivity and web-based visuals.
#
# Ans-10:-
# Hierarchical indexing, also known as MultiIndexing, in Pandas is significant because it enables the representation and manipulation of high-dimensional data like 1D, 2D.
#
# Ans-11:-
# The pairplot() function in the Seaborn library is used to visualize pairwise relationships between variables in a dataset.
#
# Ans-12:-
# The describe() function in Pandas is used to generate descriptive statistics of a DataFrame or Series.
#
# Ans-13:-
# Handling missing data in Pandas is important because it addresses potential issues that arise from incomplete datasets.
#
# Ans-14:-
# Plotly is an open-source Python library designed to create interactive, visually appealing charts and graphs. It helps users to explore data through features like zooming, additional details and clicking for deeper insights.
#
# Ans-15:-
# NumPy handles multidimensional arrays by storing all data in a contiguous block of memory.
#
# Ans-16:-
# Bokeh is a Python library that facilitates creating interactive and elegant visualizations.
#
# Ans-17:-
#   * map(): It is used to substitute each value in a Series with another value.
#   * apply(): It can be used on both Series and DataFrames.
#
# Ans-18:-
# NumPy offers advanced features beyond basic array operations, including broadcasting, linear algebra, Fourier transforms, and random number generation.
#
# Ans-19:-
# Pandas simplifies time series analysis through its specialized data structures and functions designed for handling time-indexed data. Key features include:
#
#
# Ans-20:-
# In Pandas, a pivot table serves to reshape and summarize data within a DataFrame. It transforms data from a long format to a wide format, allowing for easier analysis and comparison.
#
#
# Ans-21:-
# NumPy array slicing is faster than Python list slicing due to several factors like, homogeneous Data Types, contiguous Memory, Etc.
#
# Ans-22:-

# %% [markdown]
# #   Practical Question

# %%
#Ans- 1:-
import numpy as np
arr= np.random.randint(1,9, (3,3))
arr
# Out:
# array([[6, 2, 8],
#        [5, 6, 4],
#        [2, 5, 2]])

# %%
np.sum(arr, axis=1)
# Out:
# array([16, 15,  9])

# %%
#Ans- 2:-
import pandas as pd

data = { "Name": ["Arun", "Vikas", "Lokesh", "Rahul"],
    "Age": [25, 30, 22, 28]}

df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age
# 0    Arun   25
# 1   Vikas   30
# 2  Lokesh   22
# 3   Rahul   28

# %%
age_mean= df["Age"].mean()
print(age_mean)
# Out:
# 26.25

# %%
#Ans- 3:-
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [5, 7, 4, 6, 8]
plt.scatter(x,y)

# %%
#Ans- 4:-
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = { "Math": [85, 90, 78, 92, 88],
    "Science": [89, 94, 75, 90, 85],
    "English": [78, 85, 80, 87, 82]}

df = pd.DataFrame(data)

# %%
m= df.corr()
m
# Out:
#              Math   Science   English
# Math     1.000000  0.868831  0.763501
# Science  0.868831  1.000000  0.500492
# English  0.763501  0.500492  1.000000

# %%
Ans- 5:-

# %%
#Ans- 6:-
import pandas as pd

data = { "Name": ["Arun", "Vikas", "Lokesh", "Rahul"],
    "Age": [25, 30, 22, 28]}

df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age
# 0    Arun   25
# 1   Vikas   30
# 2  Lokesh   22
# 3   Rahul   28

# %%
df["Age after 5 Years"] = df["Age"] + 5
print(df)
# Out:
#      Name  Age  Age after 5 Years
# 0    Arun   25                 30
# 1   Vikas   30                 35
# 2  Lokesh   22                 27
# 3   Rahul   28                 33

# %%
#Ans- 7:-
import numpy as np

arr1= np.random.randint(1,9,(3,3))
arr2= np.random.randint(5,16,(3,3))

# %%
arr1
# Out:
# array([[3, 2, 8],
#        [8, 6, 6],
#        [5, 1, 8]])

# %%
arr2
# Out:
# array([[10, 11,  8],
#        [ 8, 12,  5],
#        [14,  8, 13]])

# %%
multiplay= arr1* arr2
print(multiplay)
# Out:
# [[ 30  22  64]
#  [ 64  72  30]
#  [ 70   8 104]]

# %%
#Ans- 8:-
import matplotlib.pyplot as plt

# %%
#Ans- 9:-
import pandas as pd

data = { "Name": ["Arun", "Vikas", "Lokesh", "Rahul"],
    "Score": [90, 72, 76, 55]}

df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Score
# 0    Arun     90
# 1   Vikas     72
# 2  Lokesh     76
# 3   Rahul     55

# %%
df1 = df[df["Score"] > 70]
print(df1)
# Out:
#      Name  Score
# 0    Arun     90
# 1   Vikas     72
# 2  Lokesh     76

# %%
#Ans- 10:-
import seaborn as sns
import matplotlib.pyplot as plt
# Let's say these are student test scores
scores = [55, 60, 65, 70, 72, 75, 78, 80, 82, 85, 87, 88, 90, 92, 95, 97, 100]
sns.histplot(scores, bins=10, kde=True, color="skyblue")
# Out:
# <Axes: ylabel='Count'>

# %%
#Ans- 11:-
import numpy as np
A = np.array([[1, 2, 3],
              [4, 5, 6]])

B = np.array([[7, 8],
              [9, 10],
              [11, 12]])

result = np.dot(A, B)
print(result)
# Out:
# [[ 58  64]
#  [139 154]]

# %%
#Ans- 12:-
import pandas as pd
df= pd.read_csv("services.csv", header= None)
df
# Out:
#     0            1           2                         3   \
# 0   id  location_id  program_id         accepted_payments
# 1    1            1         NaN                       NaN
# 2    2            2         NaN                       NaN
# 3    3            3         NaN                       NaN
# 4    4            4         NaN                       NaN
# 5    5            5         NaN                       NaN
# 6    6            6         NaN                       NaN
# 7    7            7         NaN                       NaN
# 8    8            8         NaN                       NaN
# 9    9            9         NaN                       NaN
# 10  10           10         NaN                       NaN
# 11  11           11         NaN                       NaN
# 12  12           12         NaN                       NaN
# 13  13           13         NaN                       NaN
# 14  14           14         NaN                       NaN
# ...

# %%
df.head(5)
# Out:
#    0            1           2                  3               4   \
# 0  id  location_id  program_id  accepted_payments  alternate_name
# 1   1            1         NaN                NaN             NaN
# 2   2            2         NaN                NaN             NaN
# 3   3            3         NaN                NaN             NaN
# 4   4            4         NaN                NaN             NaN
#
#                                             5   \
# 0                          application_process
# 1                   Walk in or apply by phone.
# 2           Apply by phone for an appointment.
# 3  Phone for information (403-4300 Ext. 4322).
# 4                              Apply by phone.
#
#                                                   6   \
# 0                                           audience
# 1  Older adults age 55 or over, ethnic minorities...
# 2       Residents of San Mateo County age 55 or over
# 3  Older adults age 55 or over who can benefit fr...
# ...

# %%
#Ans- 13:-
import plotly.graph_objects as go
x = [1, 2, 3, 4, 5]
y = [10, 15, 13, 17, 14]
z = [5, 6, 7, 8, 9]
